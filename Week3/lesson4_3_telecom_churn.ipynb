# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../../data/telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# # 1. Признаки по одному
# ## 1.1. Числові
# Гістограма і боксплот

# %%
df['Total day minutes'].hist();

# %%
sns.boxplot(df['Total day minutes']);

# %%
df.hist();

# %% [markdown]
# # 1.2. Категоріальні
# countplot

# %%
df['State'].value_counts().head()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OH     78
# Name: State, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
sns.countplot(df['Churn']);

# %%
sns.countplot(df['State']);

# %%
sns.countplot(df[df['State'].\
                 isin(df['State'].value_counts().head().index)]['State']);

# %% [markdown]
# # 2. Взаємодія признаків
# ## 2.1. Числові з числовими
# pairplot, scatterplot, кореляції, heatmap

# %%
feat = [f for f in df.columns if 'charge' in f]

df[feat].hist();

# %%
sns.pairplot(df[feat]);

# %%
df['Churn'].map({False: 'blue', True: 'orange'}).head()
# Out:
# 0    blue
# 1    blue
# 2    blue
# 3    blue
# 4    blue
# Name: Churn, dtype: object

# %%
df[~df['Churn']].head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
plt.scatter(df[df['Churn']]['Total eve charge'], 
            df[df['Churn']]['Total intl charge'],
           color='orange', label='churn');
plt.scatter(df[~df['Churn']]['Total eve charge'], 
            df[~df['Churn']]['Total intl charge'],
           color='blue', label='loyal');
plt.xlabel('Вечірні нарахування');
plt.ylabel('Міжнародні нарахування');
plt.title('Розподіл нарахувань для лояльних/пішовших');
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /mnt/storage/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total eve charge'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a9c42b54862b> in <module>()
# ----> 1 plt.scatter(df[df['Churn']]['Total eve charge'],
#       2             df[df['Churn']]['Total intl charge'],
#       3            color='orange', label='churn');
#       4 plt.scatter(df[~df['Churn']]['Total eve charge'],
#       5             df[~df['Churn']]['Total intl charge'],
#
# /mnt/storage/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /mnt/storage/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /mnt/storage/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /mnt/storage/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /mnt/storage/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total eve charge'

# %%
sns.heatmap(df.corr());

# %%
df.drop(feat, axis=1, inplace=True)

# %%
sns.heatmap(df.corr());

# %% [markdown]
# ## 2.2.  Числовий з категоріальним
# boxplot, violinplot

# %%
sns.boxplot(x='Churn', y='Total day minutes', data=df);

# %%
sns.boxplot(x='State', y='Total day minutes', data=df);

# %%
sns.violinplot(x='Churn', y='Total day minutes', data=df);

# %%
df.groupby('International plan')['Total day minutes'].mean()
# Out:
# International plan
# No     178.893887
# Yes    187.986997
# Name: Total day minutes, dtype: float64

# %%
sns.boxplot(x='International plan', y='Total day minutes', data=df);

# %% [markdown]
# ## 2.3. Категоріальний з категоріальним
# countplot

# %%
pd.crosstab(df['Churn'], df['International plan'])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
sns.countplot(x='International plan', hue='Churn', data=df);

# %%
sns.countplot(x='Customer service calls', hue='Churn', data=df);

# %% [markdown]
# ## 3. Інші
# Manifold learning, один з представників – t-SNE

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(random_state=0)

# %%
df2 = df.drop(['State', 'Churn'], axis=1)

# %%
df2['International plan'] = df2['International plan'].map({'Yes': 1, 
                                                             'No': 0})
df2['Voice mail plan'] = df2['Voice mail plan'].map({'Yes': 1, 
                                                             'No': 0})

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 14 columns):
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null int64
# Voice mail plan           3333 non-null int64
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Customer service calls    3333 non-null int64
# dtypes: float64(4), int64(10)
# memory usage: 364.6 KB

# %%
# %%time
tsne.fit(df2)
# Out:
# CPU times: user 1min 7s, sys: 29.8 s, total: 1min 36s
# Wall time: 1min 36s
# TSNE(angle=0.5, early_exaggeration=12.0, init='random', learning_rate=200.0,
#    method='barnes_hut', metric='euclidean', min_grad_norm=1e-07,
#    n_components=2, n_iter=1000, n_iter_without_progress=300,
#    perplexity=30.0, random_state=0, verbose=0)

# %%
plt.scatter(tsne.embedding_[df['Churn'].values, 0], 
            tsne.embedding_[df['Churn'].values, 1], 
            color='orange', alpha=.7);
plt.scatter(tsne.embedding_[~df['Churn'].values, 0], 
            tsne.embedding_[~df['Churn'].values, 1], 
            color='blue', alpha=.7);
